# %%
pip install sentencepiece
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: sentencepiece in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a4772a58-3696-41b0-a844-a7a5f0ac6d0c/lib/python3.9/site-packages (0.1.97)
# Python interpreter will be restarted.

# %%
import mlflow
import pandas as pd
import time
from pyspark.sql import functions as F
from pyspark.sql.types import *

# identify the model we'll pull from the model registry
model_name = "m2m100_translation_transformer" 

#start timing things 
start = time.time()

# pashto and english phrases the 'MEANING' column is in pashto, lets load that and translate it 
deltaDF = spark.read.table('kenjohnson_demo.default.train_ruen_df_short')
deltaDF = deltaDF.toPandas()
count = deltaDF['original'].count()
display( count )
sourcelang = "ru"  
targetlang = "en" 
df_source = pd.DataFrame({'id':[_ for _ in range(count)]})
df_source['content'] = deltaDF['original'].astype(str)
# Out:
# 7000

# %%
#Uncomment this to use only 64 values for debugging purposes.
#df_source = df_source[df_source['id'].isin(df_source['id'].value_counts().head(64).index)]

# %%
# convert pandas dataframe to Spark dataframe, and force Spark to partition the dataframe across all available executors
df_source_spark = spark.createDataFrame(df_source).repartition(spark.sparkContext.defaultParallelism).cache()

# %%
# inferencing function we'll distribute as a Pandas UDF
def translation_predictions_function(df):
    translation_loaded = mlflow.pyfunc.load_model(f"models:/{model_name}/Staging")
    ##mlflow.pyfunc.PythonModel enforces a one argument predict function so we use a tuple to send in our params
    param_dict = {'src_lang': 'ru', 'target_lang': 'en', 'batch_size': 8}
    model_input = ([df, param_dict])
    return translation_loaded.predict(model_input)
  
# the Spark Pandas function API requires a return value schema
schema = StructType(
    [
      StructField("id", LongType(), True),
      StructField("content", StringType(), True),
      StructField("translation", StringType(), True)
    ]
)
#ArrayType(StringType())
inferencingStartTime = time.time()
# actual translation inference on the Spark dataframe
df_source_translation = (
    df_source_spark\
    .groupBy(F.spark_partition_id().alias("_pid"))\
    .applyInPandas(translation_predictions_function, schema)
).cache()
df_source_translation.write.mode("overwrite").format("noop").save()

# viewing the results dataframe in a Databricks notebook
display(df_source_translation)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>content</th><th>translation</th></tr></thead><tbody><tr><td>1300</td><td>Теперь я поднимаю свой бокал, чтобы пожелать вам счастья; и желаю добрым людям безопасной жизни.</td><td>Now I raise my glass to wish you happiness; and I wish good people a safe life.</td></tr><tr><td>483</td><td>Беспечальному сон сладок.</td><td>The safe sleep is sweet.</td></tr><tr><td>831</td><td>при опросе других модераторов было решено не передавать саб никому, а его сделать приватным , что и сделано.</td><td>During the survey of other moderators, it was decided not to transfer the sab to anyone, but to make it private, what has been done.</td></tr><tr><td>1532</td><td>На кладбище тоже никто не выходит на протестные акции</td><td>No one goes to the cemetery to protest.</td></tr><tr><td>617</td><td>Искусство рекламы</td><td>Art of Advertising</td></tr><tr><td>1152</td><td>Бейся не бейся: без року смерти не будет.</td><td>Don’t be afraid: without the year of death there will be no death.</td></tr><tr><td>1455</td><td>Каковы сами, таковы и сани.</td><td>So are they, so are they, so are they.</td></tr><tr><td>1062</td><td>> И вот с тех самых пор есть у меня пунктик:</td><td>“I have a point since then:</td></tr><tr><td>1981</td><td>Позднему гостю — кости.</td><td>The late guest is the bones.</td></tr><tr><td>176</td><td>Зачем Россия тратит огромные деньги на содержание заполярных колоний?</td><td>Why does Russia spend a huge amount of money on the maintenance of zapolar colonies?</td></tr><tr><td>2386</td><td>Я могу глаза расслабить при этом я могу видеть то что лежит вблизи, как будто оно далеко...</td><td>I can relax my eyes while I can see what is near, as if it is far away.</td></tr><tr><td>3044</td><td>Киев назвал условия возобновления прямых поставок российского газа.....</td><td>Kiev has called the conditions for the renewal of direct supplies of Russian gas.</td></tr><tr><td>3697</td><td>Законопроект был разработан в рамках исполнения Национального плана развития конкуренции на 2018 - 2020 годы.</td><td>The draft law was developed within the framework of the implementation of the National Competition Development Plan for 2018-2020.</td></tr><tr><td>4394</td><td>У писателя скоро концерт в Киеве</td><td>The writer will soon have a concert in Kiev.</td></tr><tr><td>5031</td><td>За собой слова не удержав, за людьми не удерживают.</td><td>They do not hold the words behind themselves, they do not hold the people.</td></tr><tr><td>5949</td><td>Состояние права при Путине – хуже, чем при генсеках и императорах ::</td><td>The state of law with Putin is worse than with the gensecs and the emperors:</td></tr><tr><td>6897</td><td>Где ни напьётся, тут и подерётся.</td><td>Wherever it is drunk, there it will be.</td></tr><tr><td>320</td><td>Лондон раскрыл это, чтобы убедить союзников, что Скрипалей отравил Кремль</td><td>London revealed this to convince allies that Skripal was poisoned by the Kremlin</td></tr><tr><td>98</td><td>Кто в лес, кто по дрова.</td><td>Who is in the forest, who is in the wood?</td></tr><tr><td>760</td><td>Мягко стелет, жёстко спать.</td><td>Soft steel, hard to sleep.</td></tr><tr><td>2471</td><td>Была бы падаль, а вороньё налетит.</td><td>It would fall, and the bridge would fly.</td></tr><tr><td>1829</td><td>Jingalamo в исполнении Jahongir Otajonov,</td><td>Jingalamo performed by Jahongir Otajonov,</td></tr><tr><td>1713</td><td>Не погоняй кнутом, погоняй овсом.</td><td>Do not pursue the knot, pursue the sheep.</td></tr><tr><td>3109</td><td>Либерализм стал четкой и оформленной идеологией, требующей повсеместно выполнения одних и тех же установок.</td><td>Liberalism has become a clear and structured ideology that requires the entirely implementation of the same establishments.</td></tr><tr><td>2797</td><td>Федька горек, что редька.</td><td>Fede Gork, that is rare.</td></tr><tr><td>2170</td><td>— Без вопросов.</ ...

# %%
inferencingEndTime = time.time()
totalInferencingTime = inferencingEndTime - inferencingStartTime
dataRowCount = df_source["id"].count()

print (f"{dataRowCount} Source phrases were translated. Inferencing phase took {totalInferencingTime} seconds on {df_source_spark.rdd.getNumPartitions()} total nodes.")
# Out:
# 7000 Source phrases were translated. Inferencing phase took 247.0834527015686 seconds on 64 total nodes.

# %%
print(df_source_spark.rdd.getNumPartitions())
# Out:
# 64
